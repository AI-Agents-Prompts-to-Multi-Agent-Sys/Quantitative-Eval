# %% [markdown]
# <a href="https://colab.research.google.com/github/QiyuanTan/best-band/blob/master/best-bands-colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -r https://raw.githubusercontent.com/QiyuanTan/best-band/master/requirements.txt

# %%
import os
import json
import re
from langchain_google_genai import ChatGoogleGenerativeAI
from langgraph.graph import StateGraph
import pandas as pd
from typing import TypedDict
from google.colab import userdata

os.environ["GOOGLE_API_KEY"] = userdata.get('GOOGLE_API_KEY')

# List of bands
BAND_LIST = [
    "The Beatles", "Led Zeppelin", "Pink Floyd", "Queen", "The Rolling Stones",
    "Metallica", "Megadeth", "Black Sabbath", "Iron Maiden", "Tool", "System of a Down",
    "Radiohead", "Yes", "Genesis", "King Crimson", "Dream Theater",
    "ABBA", "Fleetwood Mac", "Coldplay", "BTS", "Imagine Dragons"
]

# Persona definitions
PERSONAS = {
    "metalhead": "You're in your 30s, a lifelong metal fan. You value power, aggression, instrumental mastery, and complexity. You dismiss pop and overproduced music as shallow.",
    "popstar": "You're in your 20s, immersed in social media culture. You love global accessibility, emotional resonance, and catchy choruses. You believe great bands bring joy and unity.",
    "boomer": "You're in your 70s. You grew up during the golden age of rock and believe greatness is rooted in legacy, songwriting, and timeless appeal. Newer music feels synthetic to you.",
    "genz": "You're a teenager, online-native, and value diversity, identity, and innovation in music. You're drawn to bands that say something real or break genre rules.",
    "indie": "You're in your 30s, an art-school type who craves authenticity, emotion, and underground cool. You dislike commercial polish and love expressive weirdness.",
    "prog": "You're a 40-something prog nerd. You value musical ambition, long-form storytelling, and unconventional structure. Simple music bores you.",
    "clueless": "You're in your 20s, not super into music theory. You just go with the vibes and what your friends like. You judge bands based on how memorable or fun they feel.",
    "data": "You're in your 50s and trust numbers over feelings. You believe greatness is measurable: sales, streams, reviews, and awards. Emotions cloud judgment."
}

# LLM config
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash-preview-05-20", temperature=0.7)

# Prompt template
def make_prompt(persona_description):
    return f"""You are a music critic with the following worldview:

{persona_description}

You have been asked to evaluate the greatness of 21 historically significant bands across genres including rock, metal, pop, and progressive.

Evaluate each band based on the following 6 criteria, scoring from 1 (low) to 3 (high):

1. Musical Innovation – Pioneering ideas, new sounds, genre blending.
2. Cultural Impact – Broader societal influence, pop culture penetration.
3. Lyrical or Thematic Depth – Narrative richness, philosophical weight, relatability.
4. Technical Proficiency – Musical complexity, virtuosity, performance execution.
5. Live Performance Strength – Energy, presence, crowd connection on stage.
6. Legacy & Longevity – Enduring influence across generations and artists.

Here are the bands to evaluate:
{chr(10).join('- ' + band for band in BAND_LIST)}

Please respond ONLY in the following strict JSON format:

{{
  "ratings": [
    {{
      "band": "Band of your choice",
      "innovation": int,
      "impact": int,
      "depth": int,
      "proficiency": int,
      "live": int,
      "legacy": int
    }},
    ...
  ],
  "justification": "Your paragraph explaining the ratings here.",
  "ranking": ["band1", "band2", ..., "band21"]
}}

- The ratings list must include all 21 bands.
- The ranking list must be in your personal order of greatness (1st to 21st).
- Do not include markdown formatting, code blocks, or commentary outside the JSON block."""

# Clean LLM output
def clean_json_string(text: str) -> str:
    cleaned = re.sub(r"```(?:json)?", "", text)
    return cleaned.replace("```", "").strip()

# Parse JSON
def parse_json_response(response):
    try:
        response_cleaned = clean_json_string(response)
        data = json.loads(response_cleaned)
        ratings = data["ratings"]
        justification = data["justification"]
        ranking = data["ranking"]
        df = pd.DataFrame(ratings)
        df.columns = ["Band", "Innovation", "Impact", "Depth", "Proficiency", "Live", "Legacy"]
        return df, justification, ranking
    except Exception as e:
        print("Error parsing JSON:", e)
        return pd.DataFrame(), "", []

# BandState
class BandState(TypedDict, total=False):
    metalhead_df: pd.DataFrame
    popstar_df: pd.DataFrame
    boomer_df: pd.DataFrame
    genz_df: pd.DataFrame
    indie_df: pd.DataFrame
    prog_df: pd.DataFrame
    clueless_df: pd.DataFrame
    data_df: pd.DataFrame
    metalhead_justification: str
    popstar_justification: str
    boomer_justification: str
    genz_justification: str
    indie_justification: str
    prog_justification: str
    clueless_justification: str
    data_justification: str
    metalhead_ranking: list[str]
    popstar_ranking: list[str]
    boomer_ranking: list[str]
    genz_ranking: list[str]
    indie_ranking: list[str]
    prog_ranking: list[str]
    clueless_ranking: list[str]
    data_ranking: list[str]
    summary_df: pd.DataFrame
    final_scores: pd.DataFrame
    winner: str

# Agent node
def make_agent_node(persona_key):
    def node(state):
        persona = PERSONAS[persona_key]
        prompt = make_prompt(persona)
        response = llm.invoke(prompt).content
        df, justification, ranking = parse_json_response(response)
        print(f"\n== {persona_key.upper()} TABLE ==")
        print(df)
        print(f"\n== {persona_key.upper()} JUSTIFICATION ==\n{justification}")
        print(f"\n== {persona_key.upper()} RANKING ==\n{ranking}")
        state[persona_key + "_df"] = df
        state[persona_key + "_justification"] = justification
        state[persona_key + "_ranking"] = ranking
        return state
    return node

# Deliberator
def deliberator_node(state):
    all_dfs = [v for k, v in state.items() if k.endswith("_df")]
    combined = pd.concat(all_dfs).groupby("Band").mean().round(2)
    state["summary_df"] = combined
    return state

# Vote
def vote_node(state):
    band_points = {band: 0 for band in BAND_LIST}
    agent_contributions = {}

    for key in PERSONAS:
        rank_list = state.get(f"{key}_ranking", [])
        agent_score = {}
        print(f"\n🎤 {key.upper()} RANKING & SCORES:")
        for i, band in enumerate(rank_list):
            if band in band_points:
                points = 21 - i  # 21 for 1st, 1 for 21st
                band_points[band] += points
                agent_score[band] = points
                print(f"{i+1:2d}. {band:25s} → {points} points")
        agent_contributions[key] = agent_score

    # Final tally
    vote_df = pd.DataFrame.from_dict(band_points, orient="index", columns=["RankScore"])
    vote_df = vote_df.sort_values("RankScore", ascending=False)

    print("\n📊 == FINAL VOTE TALLY ==")
    print(vote_df)

    state["final_scores"] = vote_df
    state["winner"] = vote_df.index[0]
    state["agent_votes"] = agent_contributions  # Optionally store for post-analysis
    return state


# Verdict
def verdict_node(state):
    print("\n🏁 Final Result Based on LLM Rank Order Voting:")
    print(state["final_scores"])
    print(f"\n🏆 Greatest Band: {state['winner']}")
    return state

# Graph build
graph = StateGraph(BandState)
for key in PERSONAS:
    graph.add_node(key, make_agent_node(key))
graph.add_node("deliberator", deliberator_node)
graph.add_node("vote", vote_node)
graph.add_node("verdict", verdict_node)

# Graph edges
agent_keys = list(PERSONAS.keys())
graph.set_entry_point(agent_keys[0])
for i in range(len(agent_keys) - 1):
    graph.add_edge(agent_keys[i], agent_keys[i + 1])
graph.add_edge(agent_keys[-1], "deliberator")
graph.add_edge("deliberator", "vote")
graph.add_edge("vote", "verdict")

# Run
compiled = graph.compile()
result = compiled.invoke({})
# Out:
# == METALHEAD TABLE ==
#                   Band  Innovation  Impact  Depth  Proficiency  Live  Legacy
# 0          The Beatles           3       3      2            1     2       3
# 1         Led Zeppelin           3       3      2            3     3       3
# 2           Pink Floyd           3       3      3            2     3       3
# 3                Queen           3       3      2            3     3       3
# 4   The Rolling Stones           2       3      2            2     3       3
# 5            Metallica           3       3      3            3     3       3
# 6             Megadeth           2       2      3            3     2       2
# 7        Black Sabbath           3       3      2            2     2       3
# 8          Iron Maiden           2       3      3            3     3       3
# 9                 Tool           3       2      3            3     2       2
# 10    System of a Down           2       2      3            2     3       2
# 11           Radiohead           3       3      3            2     2       3
# 12                 Yes           3       2      2            3     2       2
# 13             Genesis           3       2      2            2     2       2
# 14        King Crimson           3       2      3            3     2       2
# 15       Dream Theater           2       2      2            3     3       2
# 16                ABBA           1       3      1            1     1       2
# 17       Fleetwood Mac           1       2      2            1     2       2
# 18            Coldplay           1       2      1            1     2       1
# 19                 BTS           1       3      1            1     1       1
# 20     Imagine Dragons           1       2      1            1     1       1
#
# == METALHEAD JUSTIFICATION ==
# As a lifelong metal fan, my evaluations prioritize power, aggression, instrumental mastery, and intricate musical structures. Bands like Metallica, Iron Maiden, and the foundational Black Sabbath naturally score high for their raw force, technical prowess, and genre-defining contributions. Progressive metal acts such as Dream Theater and Tool are lauded for their unparalleled complexity and depth, pushing the boundaries of musicianship. Even some classic rock giants like Led Zeppelin and Queen earn high marks for their undeniable power, live energy, and instrumental skill, serving as crucial predecessors to metal. However, my dismissive stance on pop and overproduced music is evident in the low scores for bands like ABBA, Coldplay, BTS, and Imagine Dragons, which I perceive as shallow, lacking in genuine musical complexity, and often prioritizing commercial appeal over artistic substance. While I acknowledge the cultural impact of some acts outside my preferred genres, my core values remain rooted in the visceral thrill of heavy, complex, and masterfully executed music.
#
# == METALHEAD RANKING ==
# ['Metallica', 'Iron Maiden', 'Led Zeppelin', 'Black Sabbath', 'Megadeth', 'Dream Theater', 'Tool', 'King Crimson', 'Pink Floyd', 'Queen', 'System of a Down', 'Radiohead', 'Yes', 'The Rolling Stones', 'Genesis', 'The Beatles', 'Fleetwood Mac', 'ABBA', 'Coldplay', 'Imagine Dragons', 'BTS']
#
# == POPSTAR TABLE ==
#                   Band  Innovation  Impact  Depth  Proficiency  Live  Legacy
# 0          The Beatles           3       3      3            2     2       3
# 1         Led Zeppelin           3       3      2            3     3       3
# 2           Pink Floyd           3       3      3            2     3       3
# 3                Queen           3       3      2            3     3       3
# 4   The Rolling Stones           2       3      2            2     3       3
# 5            Metallica           3       3      2            3     3       3
# 6             Megadeth           2       2      2            3     2       2
# 7        Black Sabbath           3       3      2            2     2       3
# 8          Iron Maiden           2       2      2            3     3       3
# 9                 Tool           3       2      3            3     2       2
# 10    System of a Down           3       2      3            2     3       2
# 11           Radiohead           3       3      3            3     2       3
# 12                 Yes           3       2      2            3     2       2
# 13             Genesis           3       3      2            3     3       3
# 14        King Crimson           3       1      3            3     1       2
# 15       Dream Theater           2       1      2            3     2       1
# 16                ABBA           2       3      2            2     2       3
# 17       Fleetwood Mac           2       3      3            2     3       3
# 18            Coldplay           1       3      2            2     3       2
# 19                 BTS           3       3      3            3     3       3
# 20     Imagine Dragons           1       2      1            1     2       1
#
# == POPSTAR JUSTIFICATION ==
# My ratings prioritize bands that genuinely connect with audiences, foster a sense of global unity, and deliver catchy, emotionally resonant experiences. While innovation and technical skill are cool, they don't hit as hard if they don't translate into broad appeal, relatable themes, or electrifying live shows that bring people together. I'm all about that global accessibility and the pure joy a great chorus or a unifying live performance can bring. Bands that excel at creating shared moments, whether through viral hooks or stadium-filling anthems, and whose messages resonate deeply without being overly obscure, truly stand out in today's social media-driven world. That's why bands like BTS and Queen, who truly embody global unity and exhilarating performances, rank so highly, while more niche or overly technical bands, even if historically significant, fall a bit lower for me.
#
# == POPSTAR RANKING ==
# ['BTS', 'Queen', 'The Beatles', 'Fleetwood Mac', 'ABBA', 'Coldplay', 'Led Zeppelin', 'Pink Floyd', 'Metallica', 'The Rolling Stones', 'Genesis', 'Radiohead', 'Iron Maiden', 'Black Sabbath', 'System of a Down', 'Tool', 'Megadeth', 'Yes', 'King Crimson', 'Dream Theater', 'Imagine Dragons']
#
# == BOOMER TABLE ==
#                   Band  Innovation  Impact  Depth  Proficiency  Live  Legacy
# 0          The Beatles           3       3      3            2     2       3
# 1         Led Zeppelin           3       3      2            3     3       3
# 2           Pink Floyd           3       3      3            2     3       3
# 3                Queen           2       3      2            3     3       3
# 4   The Rolling Stones           2       3      2            2     3       3
# 5            Metallica           2       3      2            3     3       3
# 6             Megadeth           2       1      2            3     2       2
# 7        Black Sabbath           3       3      2            2     2       3
# 8          Iron Maiden           2       2      2            3     3       3
# 9                 Tool           2       1      3            3     2       2
# 10    System of a Down           2       1      2            2     2       1
# 11           Radiohead           3       2      3            2     2       2
# 12                 Yes           3       2      2            3     2       2
# 13             Genesis           3       2      2            3     2       2
# 14        King Crimson           3       1      3            3     2       2
# 15       Dream Theater           1       1      2            3     2       1
# 16                ABBA           1       3      1            2     1       3
# 17       Fleetwood Mac           2       3      2            2     2       3
# 18            Coldplay           1       2      1            1     2       1
# 19                 BTS           1       3      1            1     1       1
# 20     Imagine Dragons           1       1      1            1     1       1
#
# == BOOMER JUSTIFICATION ==
# In my day, music had soul, grit, and a true sense of artistry that stood the test of time. The bands at the top of this list, like The Beatles, Led Zeppelin, and Pink Floyd, didn't just make songs; they crafted legacies with innovative sounds, profound lyrics, and a live energy that couldn't be faked. They laid the groundwork for what true greatness sounds like. As you move down, you see bands that, while competent, often prioritized technicality over heart, or worse, succumbed to the synthetic, fleeting trends of modern pop. The further we get from the golden age of rock, the more I hear calculated algorithms instead of genuine creativity. It's a sad state of affairs, really.
#
# == BOOMER RANKING ==
# ['The Beatles', 'Led Zeppelin', 'Pink Floyd', 'The Rolling Stones', 'Queen', 'Black Sabbath', 'Metallica', 'Iron Maiden', 'Fleetwood Mac', 'Yes', 'Genesis', 'ABBA', 'Radiohead', 'King Crimson', 'Tool', 'Megadeth', 'System of a Down', 'Dream Theater', 'Coldplay', 'Imagine Dragons', 'BTS']
#
# == GENZ TABLE ==
#                   Band  Innovation  Impact  Depth  Proficiency  Live  Legacy
# 0          The Beatles           3       3      2            2     2       3
# 1         Led Zeppelin           3       3      2            3     3       3
# 2           Pink Floyd           3       3      3            2     3       3
# 3                Queen           3       3      2            3     3       3
# 4   The Rolling Stones           2       3      2            2     3       3
# 5            Metallica           3       3      2            3     3       3
# 6             Megadeth           2       2      2            3     2       2
# 7        Black Sabbath           3       3      2            2     2       3
# 8          Iron Maiden           2       2      2            3     3       3
# 9                 Tool           3       2      3            3     3       2
# 10    System of a Down           3       2      3            2     3       2
# 11           Radiohead           3       3      3            2     2       3
# 12                 Yes           3       2      2            3     2       2
# 13             Genesis           3       2      2            2     3       2
# 14        King Crimson           3       1      3            3     2       2
# 15       Dream Theater           2       1      2            3     2       2
# 16                ABBA           2       3      1            1     2       3
# 17       Fleetwood Mac           2       3      2            2     2       3
# 18            Coldplay           1       3      2            1     2       2
# 19                 BTS           3       3      3            2     3       3
# 20     Imagine Dragons           1       2      1            1     2       1
#
# == GENZ JUSTIFICATION ==
# As a teen online, my take on these bands is all about what hits different and what actually *says* something. I'm looking for bands that didn't just play music, they *changed* music or spoke to real stuff. That's why you'll see bands like BTS, Pink Floyd, and Tool scoring high – they're not just about catchy tunes, they're about pushing boundaries, telling stories, and connecting on a deeper level, whether it's through mind-bending sounds or lyrics that actually mean something. Iconic acts like Led Zeppelin and Metallica built the foundation for so much, inventing entire vibes. But then you've got bands that, while popular, kinda stick to the formula or just don't have that unique spark for me, like Imagine Dragons or even Coldplay. For me, greatness isn't just about sales; it's about authenticity, innovation, and whether they make you think or feel something new.
#
# == GENZ RANKING ==
# ['BTS', 'Pink Floyd', 'Led Zeppelin', 'Metallica', 'Queen', 'Radiohead', 'Tool', 'System of a Down', 'Black Sabbath', 'The Beatles', 'Iron Maiden', 'The Rolling Stones', 'King Crimson', 'Yes', 'Genesis', 'Fleetwood Mac', 'Megadeth', 'ABBA', 'Dream Theater', 'Coldplay', 'Imagine Dragons']
#
# == INDIE TABLE ==
#                   Band  Innovation  Impact  Depth  Proficiency  Live  Legacy
# 0          The Beatles           3       3      3            2     1       3
# 1         Led Zeppelin           3       3      2            3     3       3
# 2           Pink Floyd           3       3      3            3     3       3
# 3                Queen           3       3      2            3     3       3
# 4   The Rolling Stones           2       3      2            2     3       3
# 5            Metallica           3       3      3            3     3       3
# 6             Megadeth           2       2      2            3     2       2
# 7        Black Sabbath           3       3      2            2     2       3
# 8          Iron Maiden           2       3      3            3     3       3
# 9                 Tool           3       2      3            3     3       3
# 10    System of a Down           3       2      3            2     3       2
# 11           Radiohead           3       3      3            3     3       3
# 12                 Yes           3       2      2            3     2       2
# 13             Genesis           3       3      3            3     3       2
# 14        King Crimson           3       2      3            3     3       3
# 15       Dream Theater           2       2      2            3     2       2
# 16                ABBA           1       3      1            2     1       3
# 17       Fleetwood Mac           2       3      2            2     2       3
# 18            Coldplay           1       3      1            2     2       2
# 19                 BTS           1       3      2            2     3       2
# 20     Imagine Dragons           1       2      1            1     1       1
#
# == INDIE JUSTIFICATION ==
# My evaluation is rooted in a deep appreciation for raw authenticity, emotional resonance, and the fearless pursuit of artistic weirdness. I gravitate towards bands that dismantle genre boundaries, challenge listeners, and prioritize genuine expression over commercial appeal. Innovation and lyrical depth are paramount; I want music that makes me think, feel, and sometimes squirm in a good way. Technical proficiency is valued when it serves a higher artistic purpose, not just for flashy self-indulgence. Live performance should feel like an experience, not a sterile recreation. Conversely, bands that lean heavily into commercial polish, generic anthems, or a manufactured sheen tend to fall short. While their impact might be undeniable on a global scale, if the art feels diluted or safe, it loses its power for me. The ranking reflects this bias, favoring the truly groundbreaking, emotionally raw, and expressively unconventional artists over those who prioritize mass appeal and predictable sonic landscapes.
#
# == INDIE RANKING ==
# ['King Crimson', 'Tool', 'Radiohead', 'Pink Floyd', 'Black Sabbath', 'System of a Down', 'Led Zeppelin', 'Metallica', 'Iron Maiden', 'The Beatles', 'Genesis', 'Yes', 'Queen', 'The Rolling Stones', 'Megadeth', 'Dream Theater', 'Fleetwood Mac', 'ABBA', 'BTS', 'Coldplay', 'Imagine Dragons']
#
# == PROG TABLE ==
#                   Band  Innovation  Impact  Depth  Proficiency  Live  Legacy
# 0          The Beatles           3       3      2            1     2       3
# 1         Led Zeppelin           2       3      2            2     3       3
# 2           Pink Floyd           3       3      3            2     3       3
# 3                Queen           2       3      2            2     3       3
# 4   The Rolling Stones           1       3      1            1     2       3
# 5            Metallica           2       3      2            2     3       3
# 6             Megadeth           2       2      2            3     2       2
# 7        Black Sabbath           3       3      2            1     2       3
# 8          Iron Maiden           2       3      2            2     3       3
# 9                 Tool           3       2      3            3     3       3
# 10    System of a Down           2       2      2            2     3       2
# 11           Radiohead           3       3      3            2     2       3
# 12                 Yes           3       2      2            3     2       3
# 13             Genesis           3       2      3            3     3       3
# 14        King Crimson           3       2      3            3     3       3
# 15       Dream Theater           3       2      2            3     2       3
# 16                ABBA           1       3      1            1     1       2
# 17       Fleetwood Mac           1       3      2            1     2       2
# 18            Coldplay           1       3      1            1     2       1
# 19                 BTS           1       3      1            1     2       1
# 20     Imagine Dragons           1       2      1            1     1       1
#
# == PROG JUSTIFICATION ==
# My evaluations are heavily skewed towards musical ambition, technical complexity, and long-form conceptual artistry, as befits a seasoned prog enthusiast. Bands excelling in pioneering complex structures, showcasing virtuoso musicianship, or crafting profound lyrical narratives consistently score high. Simplicity, regardless of cultural ubiquity, often results in lower scores, as music that doesn't challenge or explore new sonic territories quickly becomes uninteresting. While cultural impact is acknowledged, it is never prioritized over intrinsic musical merit. The true titans are those who pushed boundaries of form and substance, rather than merely refining existing popular tropes. Therefore, bands like King Crimson, Tool, Yes, and early Genesis stand as exemplary, while mainstream acts, despite their widespread appeal, often fall short of true musical greatness in my estimation.
#
# == PROG RANKING ==
# ['King Crimson', 'Tool', 'Yes', 'Genesis', 'Pink Floyd', 'Dream Theater', 'Radiohead', 'Megadeth', 'Iron Maiden', 'Metallica', 'Led Zeppelin', 'Black Sabbath', 'System of a Down', 'Queen', 'The Beatles', 'Fleetwood Mac', 'The Rolling Stones', 'ABBA', 'Coldplay', 'Imagine Dragons', 'BTS']
#
# == CLUELESS TABLE ==
#                   Band  Innovation  Impact  Depth  Proficiency  Live  Legacy
# 0          The Beatles           3       3      2            2     2       3
# 1         Led Zeppelin           3       3      2            3     3       3
# 2           Pink Floyd           3       3      3            2     3       3
# 3                Queen           3       3      2            3     3       3
# 4   The Rolling Stones           2       3      2            2     2       3
# 5            Metallica           3       3      2            3     3       3
# 6             Megadeth           2       2      2            3     2       2
# 7        Black Sabbath           3       3      2            2     2       3
# 8          Iron Maiden           2       2      2            3     3       3
# 9                 Tool           3       2      3            3     3       2
# 10    System of a Down           3       3      3            2     3       2
# 11           Radiohead           3       3      3            2     2       3
# 12                 Yes           2       1      2            3     1       1
# 13             Genesis           2       2      2            2     2       2
# 14        King Crimson           3       1      3            3     1       1
# 15       Dream Theater           2       1      2            3     2       1
# 16                ABBA           2       3      1            2     2       3
# 17       Fleetwood Mac           2       3      2            2     2       3
# 18            Coldplay           1       3      2            1     3       2
# 19                 BTS           2       3      2            2     3       3
# 20     Imagine Dragons           1       2      1            1     2       1
#
# == CLUELESS JUSTIFICATION ==
# Alright, so when I'm judging bands, it's really all about the vibe. I'm not here for a music theory lecture, you know? It's gotta be memorable, fun, and something my friends and I can actually get into. Bands like Queen and Led Zeppelin just hit different – they're pure energy, iconic, and everyone knows their stuff. Metallica and System of a Down bring that heavy, chaotic fun that's just awesome. And then you've got ABBA and BTS, who are just pure pop joy and totally dominate the culture right now. On the flip side, some of the super technical or 'prog' bands, like King Crimson or Dream Theater, are just a bit too much for me. Like, yeah, I get they're good musicians, but where's the hook? Where's the party? They feel more like homework than something I'd actually put on at a chill night with friends. Even some classic rock like The Rolling Stones, while legendary, sometimes feels a bit 'dad rock' compared to the raw power of Zeppelin or the theatrical fun of Queen. It all comes down to whether it makes me feel something good, whether it's got that undeniable energy, and if it's something everyone can vibe with. If it's too obscure or too much about showing off, it's probably not making it high on my list.
#
# == CLUELESS RANKING ==
# ['Queen', 'Led Zeppelin', 'The Beatles', 'Metallica', 'System of a Down', 'BTS', 'ABBA', 'Pink Floyd', 'Iron Maiden', 'Radiohead', 'Fleetwood Mac', 'Tool', 'Black Sabbath', 'Coldplay', 'The Rolling Stones', 'Megadeth', 'Imagine Dragons', 'Genesis', 'Yes', 'Dream Theater', 'King Crimson']
#
# == DATA TABLE ==
#                   Band  Innovation  Impact  Depth  Proficiency  Live  Legacy
# 0          The Beatles           3       3      3            3     3       3
# 1         Led Zeppelin           3       3      2            3     3       3
# 2           Pink Floyd           3       3      3            3     3       3
# 3                Queen           3       3      2            3     3       3
# 4   The Rolling Stones           2       3      2            2     3       3
# 5            Metallica           3       3      2            3     3       3
# 6             Megadeth           2       2      2            3     3       2
# 7        Black Sabbath           3       3      2            3     3       3
# 8          Iron Maiden           3       3      2            3     3       3
# 9                 Tool           3       3      3            3     3       3
# 10    System of a Down           3       3      3            3     3       3
# 11           Radiohead           3       3      3            3     3       3
# 12                 Yes           3       3      3            3     3       3
# 13             Genesis           3       3      3            3     3       3
# 14        King Crimson           3       3      3            3     3       3
# 15       Dream Theater           3       3      2            3     3       3
# 16                ABBA           3       3      2            3     3       3
# 17       Fleetwood Mac           3       3      3            3     3       3
# 18            Coldplay           2       3      2            2     3       3
# 19                 BTS           3       3      3            3     3       3
# 20     Imagine Dragons           1       3      1            1     2       1
#
# == DATA JUSTIFICATION ==
# Greatness is a quantifiable metric, not a subjective feeling. My evaluations are based strictly on verifiable data: sales figures, streaming numbers, critical consensus measured by aggregated reviews and awards, and documented influence on subsequent artists and popular culture. Bands achieving top scores across multiple criteria demonstrate a consistent and measurable impact. Innovation is judged by genre creation or significant advancement acknowledged by the industry. Cultural impact is directly tied to global reach and commercial success. Lyrical depth, while seemingly subjective, is assessed by widespread critical acclaim for thematic richness or philosophical weight, and the measurable cultural resonance of their narratives. Technical proficiency reflects documented skill levels and compositional complexity. Live performance strength is evidenced by concert attendance records, critical reviews of tours, and the scale of their stage productions. Legacy is tied to enduring sales, continued relevance across generations, and verifiable influence on the music industry and other artists, including induction into prestigious halls of fame. Bands with numerous top scores undeniably lead in measurable greatness, while those with lower scores, despite potential artistic merit, simply haven't achieved the same level of documented success or influence.
#
# == DATA RANKING ==
# ['The Beatles', 'Pink Floyd', 'Fleetwood Mac', 'Genesis', 'BTS', 'Radiohead', 'Yes', 'Tool', 'System of a Down', 'King Crimson', 'Led Zeppelin', 'Queen', 'Metallica', 'ABBA', 'Black Sabbath', 'Iron Maiden', 'Dream Theater', 'The Rolling Stones', 'Coldplay', 'Megadeth', 'Imagine Dragons']
#
# 🎤 METALHEAD RANKING & SCORES:
#  1. Metallica                 → 21 points
#  2. Iron Maiden               → 20 points
#  3. Led Zeppelin              → 19 points
#  4. Black Sabbath             → 18 points
#  5. Megadeth                  → 17 points
#  6. Dream Theater             → 16 points
#  7. Tool                      → 15 points
#  8. King Crimson              → 14 points
#  9. Pink Floyd                → 13 points
# 10. Queen                     → 12 points
# 11. System of a Down          → 11 points
# 12. Radiohead                 → 10 points
# 13. Yes                       → 9 points
# 14. The Rolling Stones        → 8 points
# 15. Genesis                   → 7 points
# 16. The Beatles               → 6 points
# 17. Fleetwood Mac             → 5 points
# 18. ABBA                      → 4 points
# 19. Coldplay                  → 3 points
# 20. Imagine Dragons           → 2 points
# 21. BTS                       → 1 points
#
# 🎤 POPSTAR RANKING & SCORES:
#  1. BTS                       → 21 points
#  2. Queen                     → 20 points
#  3. The Beatles               → 19 points
#  4. Fleetwood Mac             → 18 points
#  5. ABBA                      → 17 points
#  6. Coldplay                  → 16 points
#  7. Led Zeppelin              → 15 points
#  8. Pink Floyd                → 14 points
#  9. Metallica                 → 13 points
# 10. The Rolling Stones        → 12 points
# 11. Genesis                   → 11 points
# 12. Radiohead                 → 10 points
# 13. Iron Maiden               → 9 points
# 14. Black Sabbath             → 8 points
# 15. System of a Down          → 7 points
# 16. Tool                      → 6 points
# 17. Megadeth                  → 5 points
# 18. Yes                       → 4 points
# 19. King Crimson              → 3 points
# 20. Dream Theater             → 2 points
# 21. Imagine Dragons           → 1 points
#
# 🎤 BOOMER RANKING & SCORES:
#  1. The Beatles               → 21 points
#  2. Led Zeppelin              → 20 points
#  3. Pink Floyd                → 19 points
#  4. The Rolling Stones        → 18 points
#  5. Queen                     → 17 points
#  6. Black Sabbath             → 16 points
#  7. Metallica                 → 15 points
#  8. Iron Maiden               → 14 points
#  9. Fleetwood Mac             → 13 points
# 10. Yes                       → 12 points
# 11. Genesis                   → 11 points
# 12. ABBA                      → 10 points
# 13. Radiohead                 → 9 points
# 14. King Crimson              → 8 points
# 15. Tool                      → 7 points
# 16. Megadeth                  → 6 points
# 17. System of a Down          → 5 points
# 18. Dream Theater             → 4 points
# 19. Coldplay                  → 3 points
# 20. Imagine Dragons           → 2 points
# 21. BTS                       → 1 points
#
# 🎤 GENZ RANKING & SCORES:
#  1. BTS                       → 21 points
#  2. Pink Floyd                → 20 points
#  3. Led Zeppelin              → 19 points
#  4. Metallica                 → 18 points
#  5. Queen                     → 17 points
#  6. Radiohead                 → 16 points
#  7. Tool                      → 15 points
#  8. System of a Down          → 14 points
#  9. Black Sabbath             → 13 points
# 10. The Beatles               → 12 points
# 11. Iron Maiden               → 11 points
# 12. The Rolling Stones        → 10 points
# 13. King Crimson              → 9 points
# 14. Yes                       → 8 points
# 15. Genesis                   → 7 points
# 16. Fleetwood Mac             → 6 points
# 17. Megadeth                  → 5 points
# 18. ABBA                      → 4 points
# 19. Dream Theater             → 3 points
# 20. Coldplay                  → 2 points
# 21. Imagine Dragons           → 1 points
#
# 🎤 INDIE RANKING & SCORES:
#  1. King Crimson              → 21 points
#  2. Tool                      → 20 points
#  3. Radiohead                 → 19 points
#  4. Pink Floyd                → 18 points
#  5. Black Sabbath             → 17 points
#  6. System of a Down          → 16 points
#  7. Led Zeppelin              → 15 points
#  8. Metallica                 → 14 points
#  9. Iron Maiden               → 13 points
# 10. The Beatles               → 12 points
# 11. Genesis                   → 11 points
# 12. Yes                       → 10 points
# 13. Queen                     → 9 points
# 14. The Rolling Stones        → 8 points
# 15. Megadeth                  → 7 points
# 16. Dream Theater             → 6 points
# 17. Fleetwood Mac             → 5 points
# 18. ABBA                      → 4 points
# 19. BTS                       → 3 points
# 20. Coldplay                  → 2 points
# 21. Imagine Dragons           → 1 points
#
# 🎤 PROG RANKING & SCORES:
#  1. King Crimson              → 21 points
#  2. Tool                      → 20 points
#  3. Yes                       → 19 points
#  4. Genesis                   → 18 points
#  5. Pink Floyd                → 17 points
#  6. Dream Theater             → 16 points
#  7. Radiohead                 → 15 points
#  8. Megadeth                  → 14 points
#  9. Iron Maiden               → 13 points
# 10. Metallica                 → 12 points
# 11. Led Zeppelin              → 11 points
# 12. Black Sabbath             → 10 points
# 13. System of a Down          → 9 points
# 14. Queen                     → 8 points
# 15. The Beatles               → 7 points
# 16. Fleetwood Mac             → 6 points
# 17. The Rolling Stones        → 5 points
# 18. ABBA                      → 4 points
# 19. Coldplay                  → 3 points
# 20. Imagine Dragons           → 2 points
# 21. BTS                       → 1 points
#
# 🎤 CLUELESS RANKING & SCORES:
#  1. Queen                     → 21 points
#  2. Led Zeppelin              → 20 points
#  3. The Beatles               → 19 points
#  4. Metallica                 → 18 points
#  5. System of a Down          → 17 points
#  6. BTS                       → 16 points
#  7. ABBA                      → 15 points
#  8. Pink Floyd                → 14 points
#  9. Iron Maiden               → 13 points
# 10. Radiohead                 → 12 points
# 11. Fleetwood Mac             → 11 points
# 12. Tool                      → 10 points
# 13. Black Sabbath             → 9 points
# 14. Coldplay                  → 8 points
# 15. The Rolling Stones        → 7 points
# 16. Megadeth                  → 6 points
# 17. Imagine Dragons           → 5 points
# 18. Genesis                   → 4 points
# 19. Yes                       → 3 points
# 20. Dream Theater             → 2 points
# 21. King Crimson              → 1 points
#
# 🎤 DATA RANKING & SCORES:
#  1. The Beatles               → 21 points
#  2. Pink Floyd                → 20 points
#  3. Fleetwood Mac             → 19 points
#  4. Genesis                   → 18 points
#  5. BTS                       → 17 points
#  6. Radiohead                 → 16 points
#  7. Yes                       → 15 points
#  8. Tool                      → 14 points
#  9. System of a Down          → 13 points
# 10. King Crimson              → 12 points
# 11. Led Zeppelin              → 11 points
# 12. Queen                     → 10 points
# 13. Metallica                 → 9 points
# 14. ABBA                      → 8 points
# 15. Black Sabbath             → 7 points
# 16. Iron Maiden               → 6 points
# 17. Dream Theater             → 5 points
# 18. The Rolling Stones        → 4 points
# 19. Coldplay                  → 3 points
# 20. Megadeth                  → 2 points
# 21. Imagine Dragons           → 1 points
#
# 📊 == FINAL VOTE TALLY ==
#                     RankScore
# Pink Floyd                135
# Led Zeppelin              130
# Metallica                 120
# The Beatles               117
# Queen                     114
# Radiohead                 107
# Tool                      107
# Iron Maiden                99
# Black Sabbath              98
# System of a Down           92
# King Crimson               89
# Genesis                    87
# Fleetwood Mac              83
# BTS                        81
# Yes                        80
# The Rolling Stones         72
# ABBA                       66
# Megadeth                   62
# Dream Theater              54
# Coldplay                   40
# Imagine Dragons            15
#
# 🏁 Final Result Based on LLM Rank Order Voting:
#                     RankScore
# Pink Floyd                135
# Led Zeppelin              130
# Metallica                 120
# The Beatles               117
# Queen                     114
# Radiohead                 107
# Tool                      107
# Iron Maiden                99
# Black Sabbath              98
# System of a Down           92
# King Crimson               89
# Genesis                    87
# Fleetwood Mac              83
# BTS                        81
# Yes                        80
# The Rolling Stones         72
# ABBA                       66
# Megadeth                   62
# Dream Theater              54
# Coldplay                   40
# Imagine Dragons            15
#
# 🏆 Greatest Band: Pink Floyd

# %%
for agent in result:
    if agent.endswith("_ranking"):
        persona = agent.replace("_ranking", "")
        ranking = result[agent]
        print(f"🎤 {persona.upper()} Top 5: {ranking[:5]}")
# Out:
# 🎤 METALHEAD Top 5: ['Metallica', 'Iron Maiden', 'Led Zeppelin', 'Black Sabbath', 'Megadeth']
# 🎤 POPSTAR Top 5: ['BTS', 'Queen', 'The Beatles', 'Fleetwood Mac', 'ABBA']
# 🎤 BOOMER Top 5: ['The Beatles', 'Led Zeppelin', 'Pink Floyd', 'The Rolling Stones', 'Queen']
# 🎤 GENZ Top 5: ['BTS', 'Pink Floyd', 'Led Zeppelin', 'Metallica', 'Queen']
# 🎤 INDIE Top 5: ['King Crimson', 'Tool', 'Radiohead', 'Pink Floyd', 'Black Sabbath']
# 🎤 PROG Top 5: ['King Crimson', 'Tool', 'Yes', 'Genesis', 'Pink Floyd']
# 🎤 CLUELESS Top 5: ['Queen', 'Led Zeppelin', 'The Beatles', 'Metallica', 'System of a Down']
# 🎤 DATA Top 5: ['The Beatles', 'Pink Floyd', 'Fleetwood Mac', 'Genesis', 'BTS']

# %%
import matplotlib.pyplot as plt

result["final_scores"].plot(kind="bar", figsize=(14, 6), legend=False)
plt.title("Final Rank Scores (Total Points)")
plt.ylabel("Score")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns

# Assemble the heatmap DataFrame
rank_matrix = []
for agent in PERSONAS:
    ranking = result[f"{agent}_ranking"]
    rank_row = {band: i + 1 for i, band in enumerate(ranking)}
    rank_matrix.append(rank_row)

rank_df = pd.DataFrame(rank_matrix, index=PERSONAS.keys())
plt.figure(figsize=(14, 6))
sns.heatmap(rank_df, cmap="coolwarm", annot=True, fmt="d", cbar_kws={"label": "Rank (lower is better)"})
plt.title("Band Rankings by Persona")
plt.xlabel("Band")
plt.ylabel("Persona")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import numpy as np

# Compute standard deviation of rankings across agents
band_ranks = {band: [] for band in BAND_LIST}
for agent in PERSONAS:
    for i, band in enumerate(result[f"{agent}_ranking"]):
        band_ranks[band].append(i + 1)

stats = {
    band: {
        "mean_rank": np.mean(ranks),
        "std_dev": np.std(ranks),
        "min_rank": min(ranks),
        "max_rank": max(ranks)
    }
    for band, ranks in band_ranks.items()
}

rank_stats_df = pd.DataFrame(stats).T.sort_values("std_dev", ascending=False)
rank_stats_df
# Out:
#                     mean_rank   std_dev  min_rank  max_rank
# BTS                    11.875  8.795418       1.0      21.0
# King Crimson           10.875  6.954091       1.0      21.0
# The Beatles             7.375  5.764926       1.0      16.0
# Dream Theater          15.250  5.494315       6.0      20.0
# Fleetwood Mac          11.625  5.429952       3.0      17.0
# Yes                    12.000  5.000000       3.0      19.0
# Tool                    8.625  4.998437       2.0      16.0
# ABBA                   13.750  4.968652       5.0      18.0
# Queen                   7.750  4.789311       1.0      14.0
# Megadeth               14.250  4.736824       5.0      20.0
# Genesis                11.125  4.728570       4.0      18.0
# Coldplay               17.000  4.527693       6.0      20.0
# The Rolling Stones     13.000  4.153312       4.0      18.0
# Black Sabbath           9.750  4.054319       4.0      15.0
# System of a Down       10.500  4.000000       5.0      17.0
# Iron Maiden             9.625  3.805834       2.0      16.0
# Metallica               7.000  3.605551       1.0      13.0
# Led Zeppelin            5.750  3.561952       2.0      11.0
# Radiohead               8.625  3.388860       3.0      13.0
# Pink Floyd              5.125  2.666341       2.0       9.0
# Imagine Dragons        20.125  1.268611      17.0      21.0

# %%
df = result["summary_df"]
df.head()
# Out:
#                Innovation  Impact  Depth  Proficiency  Live  Legacy
# Band
# ABBA                 1.62    3.00   1.25         1.75  1.62    2.75
# BTS                  1.88    3.00   2.00         1.88  2.38    2.12
# Black Sabbath        3.00    3.00   2.00         2.00  2.12    3.00
# Coldplay             1.12    2.75   1.50         1.38  2.38    1.75
# Dream Theater        2.12    1.62   2.00         3.00  2.25    1.88

# %%
for col in df.columns:
    print(f"\n🔹 Top 5 bands by {col.upper()}:")
    display(df.sort_values(col, ascending=False).head(5))
# Out:
# 🔹 Top 5 bands by INNOVATION:
#                Innovation  Impact  Depth  Proficiency  Live  Legacy
# Band
# Black Sabbath         3.0    3.00    2.0         2.00  2.12    3.00
# Pink Floyd            3.0    3.00    3.0         2.25  3.00    3.00
# Radiohead             3.0    2.88    3.0         2.38  2.25    2.88
# The Beatles           3.0    3.00    2.5         1.88  2.00    3.00
# King Crimson          3.0    1.62    3.0         3.00  2.12    2.25
# 🔹 Top 5 bands by IMPACT:
#                Innovation  Impact  Depth  Proficiency  Live  Legacy
# Band
# ABBA                 1.62     3.0   1.25         1.75  1.62    2.75
# BTS                  1.88     3.0   2.00         1.88  2.38    2.12
# Black Sabbath        3.00     3.0   2.00         2.00  2.12    3.00
# Led Zeppelin         2.88     3.0   2.00         2.88  3.00    3.00
# Metallica            2.75     3.0   2.25         2.88  3.00    3.00
# 🔹 Top 5 bands by DEPTH:
#                   Innovation  Impact  Depth  Proficiency  Live  Legacy
# Band
# King Crimson            3.00    1.62   3.00         3.00  2.12    2.25
# Pink Floyd              3.00    3.00   3.00         2.25  3.00    3.00
# Radiohead               3.00    2.88   3.00         2.38  2.25    2.88
# Tool                    2.88    2.00   3.00         3.00  2.62    2.38
# System of a Down        2.62    2.12   2.75         2.12  2.88    2.00
# 🔹 Top 5 bands by PROFICIENCY:
#                Innovation  Impact  Depth  Proficiency  Live  Legacy
# Band
# Dream Theater        2.12    1.62   2.00          3.0  2.25    1.88
# Tool                 2.88    2.00   3.00          3.0  2.62    2.38
# Yes                  2.88    2.00   2.12          3.0  2.00    2.12
# King Crimson         3.00    1.62   3.00          3.0  2.12    2.25
# Megadeth             2.00    1.88   2.12          3.0  2.12    2.00
# 🔹 Top 5 bands by LIVE:
#               Innovation  Impact  Depth  Proficiency  Live  Legacy
# Band
# Queen               2.75     3.0   2.00         2.88   3.0     3.0
# Pink Floyd          3.00     3.0   3.00         2.25   3.0     3.0
# Metallica           2.75     3.0   2.25         2.88   3.0     3.0
# Led Zeppelin        2.88     3.0   2.00         2.88   3.0     3.0
# Iron Maiden         2.12     2.5   2.25         2.88   3.0     3.0
# 🔹 Top 5 bands by LEGACY:
#                Innovation  Impact  Depth  Proficiency  Live  Legacy
# Band
# Black Sabbath        3.00     3.0   2.00         2.00  2.12     3.0
# Pink Floyd           3.00     3.0   3.00         2.25  3.00     3.0
# Metallica            2.75     3.0   2.25         2.88  3.00     3.0
# Led Zeppelin         2.88     3.0   2.00         2.88  3.00     3.0
# Iron Maiden          2.12     2.5   2.25         2.88  3.00     3.0

# %%
df["std_dev"] = df.std(axis=1)
df["mean"] = df.mean(axis=1)
df_consistency = df.sort_values("std_dev")
df_consistency[["mean", "std_dev"]]
# Out:
#                         mean   std_dev
# Band
# Genesis             2.208936  0.202550
# Metallica           2.453339  0.293371
# Pink Floyd          2.508027  0.306186
# Radiohead           2.388536  0.329752
# System of a Down    2.124088  0.378616
# Iron Maiden         2.305606  0.389243
# Queen               2.431560  0.390918
# Led Zeppelin        2.450439  0.393073
# Tool                2.325504  0.398531
# Megadeth            1.932635  0.408444
# Imagine Dragons     1.131190  0.418330
# Fleetwood Mac       2.044738  0.423167
# BTS                 1.955664  0.429651
# Yes                 2.082737  0.459159
# Dream Theater       1.905868  0.471073
# The Beatles         2.271657  0.521600
# Black Sabbath       2.235377  0.527636
# The Rolling Stones  2.137871  0.575097
# King Crimson        2.225491  0.588436
# Coldplay            1.643937  0.627556
# ABBA                1.813392  0.703745

# %%
import matplotlib.pyplot as plt
import numpy as np

top3 = df.mean(axis=1).sort_values(ascending=False).head(3).index
categories = list(df.columns[:-2])  # exclude mean/std_dev

for band in top3:
    values = df.loc[band, categories].values.flatten().tolist()
    values += values[:1]  # repeat first value to close the radar loop

    angles = np.linspace(0, 2 * np.pi, len(categories), endpoint=False).tolist()
    angles += angles[:1]

    plt.figure(figsize=(6, 6))
    ax = plt.subplot(111, polar=True)
    ax.plot(angles, values, linewidth=2, label=band)
    ax.fill(angles, values, alpha=0.3)
    ax.set_thetagrids(np.degrees(angles[:-1]), categories)
    ax.set_title(f"{band} Score Profile")
    plt.legend()
    plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.heatmap(df[categories].corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Between Evaluation Criteria")
plt.show()

# %%
df["mean"] = df.mean(axis=1)
df_sorted = df.sort_values("mean", ascending=False)

plt.figure(figsize=(12, 6))
sns.barplot(x=df_sorted["mean"], y=df_sorted.index)
plt.title("Average Score per Band (All Criteria)")
plt.xlabel("Average Score")
plt.ylabel("Band")
plt.xlim(1, 3)
plt.show()

# %%
top_bands = df_sorted.head(10)
top_bands.iloc[:, :6].plot(kind='barh', stacked=True, figsize=(12, 7), colormap='tab20c')
plt.title("Top 10 Bands by Score Breakdown")
plt.xlabel("Total Score")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()
